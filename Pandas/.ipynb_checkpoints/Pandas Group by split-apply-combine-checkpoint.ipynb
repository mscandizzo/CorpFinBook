# %% [markdown]
# ## Pandas Group by tools
# ---------------------

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import datetime as dt
plt.show(block=True)

# %% [markdown]
# ## List of Content
# -------------------------------
#
# 1. Clean white space
# 2. pandas reset index
# 3. Group by single field
# 4. Group --> first, last
# 5. Group --> get_group --> specific group after filtering by one category
# 6. Group by multiple fields
# 7. pandas set index
# 8. Groupby index levels
# 9. Data aggregation at index level
# 10. Data aggregation non index levels
# 11. Group -- get group --> gathering multiple fields
# 12. Group by multiple field to get specific field and data aggretion
# 13. Data aggregation -- many examples
# 14. data grouping and manipulation --> lambda functions
# 15. functions to apply to groupby --> rolling
# 16. apply functions to data after groupby

# %% [markdown]
# [Pandas Tutorial and useful reference](https://pandas.pydata.org/pandas-docs/stable/groupby.html)

# %%
datos = pd.read_excel('dump.xlsx',sheet_name='dump')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210127 entries, 0 to 210126
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       210127 non-null  int64
#  1   Store            210127 non-null  int64
#  2   UniqueField      210127 non-null  object
#  3   RECEIPTNO        210127 non-null  int64
#  4   ItemCode         208129 non-null  float64
#  5   Name             210127 non-null  object
#  6   PSA              208129 non-null  object
#  7   Category         208129 non-null  object
#  8   SubCat           208129 non-null  object
#  9   SuppCode         208129 non-null  float64
#  10  TransactionDate  210127 non-null  datetime64[ns]
#  11  QtySold          210127 non-null  int64
#  12  unitcost         208129 non-null  float64
#  13  COGS             208129 non-null  float64
#  14  SalesAmount      210127 non-null  float64
#  15  Promotion        210127 non-null  float64
#  16  YYYY-MM-DD       210127 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(4), object(5)
# memory usage: 27.3+ MB

# %%
datos.head()
# Out:
#    Unnamed: 0  Store         UniqueField  RECEIPTNO  ItemCode  \
# 0      290977      1  0000013465 4000411       3465  140103.0
# 1      290978      1  0000013466 4002402       3466  500024.0
# 2      290979      1  0000013467 4004630       3467  120022.0
# 3      290980      1  0000013468 4013146       3468   20071.0
# 4      290981      1  0000013468 4013146       3468  120058.0
#
#                                        Name                             PSA  \
# 0  SAHA EGGS MEDIUM 6 S                      Other Daily Foods
# 1  MOUNTAIN DEW 2.25L PET                    Beverage
# 2  AL AIN LABAN 500ML                        Dairy Beverages
# 3  CHICKEN CHAWERMA                          Sandwiches
# 4  ALMARAI MHR FLVRD STRAW 180 ML            Dairy Beverages
#
#                          Category                          SubCat  SuppCode  \
# 0  Egg                             Egg                                 49.0
# 1  Carbonated Beverage             Carbonated Beverage                 30.0
# 2  Other                           Other                               40.0
# 3  Wrap                            Wrap                               110.0
# 4  Flavored Milk                   Flavored Milk                       52.0
#
#   TransactionDate  QtySold  unitcost  COGS  SalesAmount  Promotion YYYY-MM-DD
# 0      2017-06-01        1      4.19  4.19         6.25        0.0 2017-06-01
# 1      2017-06-01        1      5.00  5.00         5.00        0.0 2017-06-01
# 2      2017-06-01        1      2.75  2.75         3.50        0.0 2017-06-01
# 3      2017-06-01        1      7.00  7.00        12.00        0.0 2017-06-01
# 4      2017-06-01        1      1.35  1.35         1.50        0.0 2017-06-01

# %%
((datos.SalesAmount.count() - datos.unitcost.count())/datos.unitcost.count())*100
# Out:
# 0.9599815499041461

# %%
datos.dropna(inplace=True)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208129 entries, 0 to 210126
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       208129 non-null  int64
#  1   Store            208129 non-null  int64
#  2   UniqueField      208129 non-null  object
#  3   RECEIPTNO        208129 non-null  int64
#  4   ItemCode         208129 non-null  float64
#  5   Name             208129 non-null  object
#  6   PSA              208129 non-null  object
#  7   Category         208129 non-null  object
#  8   SubCat           208129 non-null  object
#  9   SuppCode         208129 non-null  float64
#  10  TransactionDate  208129 non-null  datetime64[ns]
#  11  QtySold          208129 non-null  int64
#  12  unitcost         208129 non-null  float64
#  13  COGS             208129 non-null  float64
#  14  SalesAmount      208129 non-null  float64
#  15  Promotion        208129 non-null  float64
#  16  YYYY-MM-DD       208129 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(4), object(5)
# memory usage: 28.6+ MB

# %%
datos.reset_index(drop = True, inplace = True)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208129 entries, 0 to 208128
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       208129 non-null  int64
#  1   Store            208129 non-null  int64
#  2   UniqueField      208129 non-null  object
#  3   RECEIPTNO        208129 non-null  int64
#  4   ItemCode         208129 non-null  float64
#  5   Name             208129 non-null  object
#  6   PSA              208129 non-null  object
#  7   Category         208129 non-null  object
#  8   SubCat           208129 non-null  object
#  9   SuppCode         208129 non-null  float64
#  10  TransactionDate  208129 non-null  datetime64[ns]
#  11  QtySold          208129 non-null  int64
#  12  unitcost         208129 non-null  float64
#  13  COGS             208129 non-null  float64
#  14  SalesAmount      208129 non-null  float64
#  15  Promotion        208129 non-null  float64
#  16  YYYY-MM-DD       208129 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(4), object(5)
# memory usage: 27.0+ MB

# %% [markdown]
# ## PSA category has white spaces which makes difficult to manipulate, let us fix it

# %%
datos['PSA'] = datos['PSA'].str.strip(' ')

# %%
datos.head()
# Out:
#    Unnamed: 0  Store         UniqueField  RECEIPTNO  ItemCode  \
# 0      290977      1  0000013465 4000411       3465  140103.0
# 1      290978      1  0000013466 4002402       3466  500024.0
# 2      290979      1  0000013467 4004630       3467  120022.0
# 3      290980      1  0000013468 4013146       3468   20071.0
# 4      290981      1  0000013468 4013146       3468  120058.0
#
#                                        Name                PSA  \
# 0  SAHA EGGS MEDIUM 6 S                      Other Daily Foods
# 1  MOUNTAIN DEW 2.25L PET                             Beverage
# 2  AL AIN LABAN 500ML                          Dairy Beverages
# 3  CHICKEN CHAWERMA                                 Sandwiches
# 4  ALMARAI MHR FLVRD STRAW 180 ML              Dairy Beverages
#
#                          Category                          SubCat  SuppCode  \
# 0  Egg                             Egg                                 49.0
# 1  Carbonated Beverage             Carbonated Beverage                 30.0
# 2  Other                           Other                               40.0
# 3  Wrap                            Wrap                               110.0
# 4  Flavored Milk                   Flavored Milk                       52.0
#
#   TransactionDate  QtySold  unitcost  COGS  SalesAmount  Promotion YYYY-MM-DD
# 0      2017-06-01        1      4.19  4.19         6.25        0.0 2017-06-01
# 1      2017-06-01        1      5.00  5.00         5.00        0.0 2017-06-01
# 2      2017-06-01        1      2.75  2.75         3.50        0.0 2017-06-01
# 3      2017-06-01        1      7.00  7.00        12.00        0.0 2017-06-01
# 4      2017-06-01        1      1.35  1.35         1.50        0.0 2017-06-01

# %% [markdown]
# ## Groupby
# -------------------------------

# %%
# the UniqueField holds together all the items purchased during the same transaction.
# i.e. the basket

grouped = datos.groupby('UniqueField')
grouped.sum().sort_values(by='SalesAmount',ascending=[False]).head()
# After grouping we are summing the elements that belong to the uniquefield
# Out:
#                     Unnamed: 0  Store  RECEIPTNO    ItemCode  SuppCode  \
# UniqueField
# 0000129968 3154828      968075     24      19936   1100117.0      50.0
# 0000021416 5000236    38566281    156     110448  25838340.0   24578.0
# 0000037692 7042809     8183763     54     138456   5833515.0    1335.0
# 0000025280 5003003    16336650     66     174240  16823800.0    2227.0
# 0000066474 4153303     4439877     78      84162   6121341.0    1046.0
#
#                     QtySold  unitcost    COGS  SalesAmount  Promotion
# UniqueField
# 0000129968 3154828       80     18.16  726.40       800.00        0.0
# 0000021416 5000236       97    568.70  608.85       734.25        0.0
# 0000037692 7042809       60    197.16  494.80       590.25        0.0
# 0000025280 5003003       42    362.98  423.69       540.50        0.0
# 0000066474 4153303      110    151.27  430.19       537.75        0.0

# %%
# it sorts by ascending order
grouped.first().head(3)
# Out:
#                     Unnamed: 0  Store  RECEIPTNO  ItemCode  \
# UniqueField
# 0000013465 4000411      290977      1       3465  140103.0
# 0000013466 4002402      290978      1       3466  500024.0
# 0000013467 4004630      290979      1       3467  120022.0
#
#                                                         Name  \
# UniqueField
# 0000013465 4000411  SAHA EGGS MEDIUM 6 S
# 0000013466 4002402  MOUNTAIN DEW 2.25L PET
# 0000013467 4004630  AL AIN LABAN 500ML
#
#                                   PSA                        Category  \
# UniqueField
# 0000013465 4000411  Other Daily Foods  Egg
# 0000013466 4002402           Beverage  Carbonated Beverage
# 0000013467 4004630    Dairy Beverages  Other
#
#                                             SubCat  SuppCode TransactionDate  \
# UniqueField
# 0000013465 4000411  Egg                                 49.0      2017-06-01
# 0000013466 4002402  Carbonated Beverage                 30.0      2017-06-01
# 0000013467 4004630  Other                               40.0      2017-06-01
#
#                     QtySold  unitcost  COGS  SalesAmount  Promotion YYYY-MM-DD
# UniqueField
# 0000013465 4000411        1      4.19  4.19         6.25        0.0 2017-06-01
# 0000013466 4002402        1      5.00  5.00         5.00        0.0 2017-06-01
# 0000013467 4004630        1      2.75  2.75         3.50        0.0 2017-06-01

# %%
# it sorts by descending order
grouped.last().head(3)
# Out:
#                     Unnamed: 0  Store  RECEIPTNO  ItemCode  \
# UniqueField
# 0000013465 4000411      290977      1       3465  140103.0
# 0000013466 4002402      290978      1       3466  500024.0
# 0000013467 4004630      290979      1       3467  120022.0
#
#                                                         Name  \
# UniqueField
# 0000013465 4000411  SAHA EGGS MEDIUM 6 S
# 0000013466 4002402  MOUNTAIN DEW 2.25L PET
# 0000013467 4004630  AL AIN LABAN 500ML
#
#                                   PSA                        Category  \
# UniqueField
# 0000013465 4000411  Other Daily Foods  Egg
# 0000013466 4002402           Beverage  Carbonated Beverage
# 0000013467 4004630    Dairy Beverages  Other
#
#                                             SubCat  SuppCode TransactionDate  \
# UniqueField
# 0000013465 4000411  Egg                                 49.0      2017-06-01
# 0000013466 4002402  Carbonated Beverage                 30.0      2017-06-01
# 0000013467 4004630  Other                               40.0      2017-06-01
#
#                     QtySold  unitcost  COGS  SalesAmount  Promotion YYYY-MM-DD
# UniqueField
# 0000013465 4000411        1      4.19  4.19         6.25        0.0 2017-06-01
# 0000013466 4002402        1      5.00  5.00         5.00        0.0 2017-06-01
# 0000013467 4004630        1      2.75  2.75         3.50        0.0 2017-06-01

# %%
grouped1 = datos.groupby(['Store','PSA'])
grouped1.first().head(3)
# Out:
#                    Unnamed: 0         UniqueField  RECEIPTNO  ItemCode  \
# Store PSA
# 1     Babies           345539  0000016380 5004208       6380  670083.0
#       Bakery           290983  0000013469 4015927       3469  150073.0
#       Beauty Aids      291208  0000013603 4195649       3603  660035.0
#
#                                                        Name  \
# Store PSA
# 1     Babies       MERRIES BABY DIAPER PANTS SZ M
#       Bakery       DATE DELIGHT 50GM MODRN BAKRY
#       Beauty Aids  DOVE MENCARE INVISIBLEDRY150ML
#
#                                          Category  \
# Store PSA
# 1     Babies       Baby Supply
#       Bakery       Pastry
#       Beauty Aids  Men's Cosmetics
#
#                                            SubCat  SuppCode TransactionDate  \
# Store PSA
# 1     Babies       Baby Supply                         85.0      2017-06-09
#       Bakery       Pastry                              32.0      2017-06-01
#       Beauty Aids  Men's Cosmetics                     46.0      2017-06-01
#
#                    QtySold  unitcost    COGS  SalesAmount  Promotion  \
# Store PSA
# 1     Babies             1    53.670  53.670         72.0        0.0
#       Bakery             1     1.056   1.056          2.5        0.0
#       Beauty Aids        1    12.500  12.500         15.0        0.0
#
#                   YYYY-MM-DD
# Store PSA
# 1     Babies      2017-06-09
#       Bakery      2017-06-01
#       Beauty Aids 2017-06-01

# %%
datos.groupby(['Store']).size()
# Out:
# Store
# 1     18162
# 2     28283
# 3     19662
# 4     12114
# 5     14907
# 6     20761
# 7     19152
# 9     30407
# 10    18151
# 11    17211
# 12     9319
# dtype: int64

# %%
# To get the full list of groups you can use:
# grouped.groups
# however because is a dictionary the format is not ideal

# %%
#grouped1.groups

# %% [markdown]
# ## Groupby at Index Level
# --------------------------------------------
# 1. Grouping
# 2. aggregations

# %%
datosx = datos.set_index(['Store','YYYY-MM-DD'])

# %%
datosx.groupby(level=0).sum()
# Out:
#         Unnamed: 0  RECEIPTNO      ItemCode    SuppCode  QtySold    unitcost  \
# Store
# 1       7137671009  105814989  5.553244e+09  10186306.0    20999   70620.710
# 2      11166740471  144252996  9.819042e+09  11968520.0    35705  130323.835
# 3       7875381254  134855320  6.261713e+09   6653759.0    23254   92476.846
# 4       4739226243   74834487  4.325060e+09   4750578.0    14927   47498.791
# 5       5815294524   59879331  5.191516e+09   8101634.0    17057   56644.781
# 6       8266962600  106305673  6.229335e+09   8124846.0    23417   79283.658
# 7       7607127106   83364653  5.667253e+09   6576422.0    22846   87865.386
# 9      11987546342  136507733  9.558050e+09  13737959.0    36175  121819.501
# 10      7187013829   68311561  6.264024e+09   7032949.0    20501   70145.146
# 11      6842940501   84295225  5.131984e+09   5863503.0    19240   67663.488
# 12      3806303052   65063329  3.170008e+09   3664973.0    10826   35597.235
#
#              COGS  SalesAmount  Promotion
# Store
# 1       80064.758    105737.71     2734.5
# 2      152518.399    198017.23     1138.0
# 3      105845.816    137836.85      798.0
# 4       55272.174     71467.16      157.5
# 5       62899.182     81558.78      321.5
# 6       86508.968    115942.86      736.0
# 7       99699.761    133099.88     3553.5
# 9      138212.494    182651.84     2115.5
# 10      76169.617     99012.04      491.0
# 11      72681.668     97286.28     1429.5
# 12      40827.367     51678.78     1101.0

# %%
datosx.groupby(level='YYYY-MM-DD').sum().head(3)
# Out:
#             Unnamed: 0  RECEIPTNO      ItemCode   SuppCode  QtySold  \
# YYYY-MM-DD
# 2017-06-01  2020975214   41859378  2.173735e+09  2740522.0     7955
# 2017-06-02  1555739291   33824513  1.772427e+09  2142747.0     6297
# 2017-06-03  1759050247   38127343  1.923379e+09  2190505.0     6668
#
#              unitcost       COGS  SalesAmount  Promotion
# YYYY-MM-DD
# 2017-06-01  28748.666  32014.103     41727.10      589.5
# 2017-06-02  22282.598  25622.352     32916.69      240.5
# 2017-06-03  23947.725  26878.434     34541.06      325.5

# %%
# Important: It has to be an index level!!!

datosx.sum(level='Store').head(3)
# Out:
#         Unnamed: 0  RECEIPTNO      ItemCode    SuppCode  QtySold    unitcost  \
# Store
# 1       7137671009  105814989  5.553244e+09  10186306.0    20999   70620.710
# 2      11166740471  144252996  9.819042e+09  11968520.0    35705  130323.835
# 3       7875381254  134855320  6.261713e+09   6653759.0    23254   92476.846
#
#              COGS  SalesAmount  Promotion
# Store
# 1       80064.758    105737.71     2734.5
# 2      152518.399    198017.23     1138.0
# 3      105845.816    137836.85      798.0

# %%
datosx.groupby(['Store','PSA']).sum().head()
# Out:
#                    Unnamed: 0  RECEIPTNO      ItemCode   SuppCode  QtySold  \
# Store PSA
# 1     Babies           345539       6380  6.700830e+05       85.0        1
#       Bakery        510112265    7536369  1.979373e+08    74630.0     1443
#       Beauty Aids    18002340     258522  3.168528e+07     2212.0       48
#       Beverage     1062725076   15682505  1.336788e+09   170951.0     3202
#       Cigarette     406620438    6008876  5.671134e+08  1296531.0     1198
#
#                    unitcost      COGS  SalesAmount  Promotion
# Store PSA
# 1     Babies         53.670    53.670        72.00        0.0
#       Bakery       2875.808  3165.938      4958.25        0.0
#       Beauty Aids   784.660   784.660       949.00        0.0
#       Beverage     6346.180  7591.775      8240.25      156.0
#       Cigarette    7216.700  8904.510     10187.50        0.0

# %% [markdown]
# ## Groupby.get_group follows SQL structure
# ---------------------------------------------------------------------
#
# get group must have as many filters as the initial group by has, i.e. --> 1 to 1 , 2 to 2, etc.

# %%
datosx.groupby(['PSA']).get_group('Sandwiches').head(3)
# Out:
#                   Unnamed: 0         UniqueField  RECEIPTNO  ItemCode  \
# Store YYYY-MM-DD
# 1     2017-06-01      290980  0000013468 4013146       3468   20071.0
#       2017-06-01      291019  0000013493 4073004       3493   20055.0
#       2017-06-01      291053  0000013511 4111201       3511   20020.0
#
#                                                       Name         PSA  \
# Store YYYY-MM-DD
# 1     2017-06-01  CHICKEN CHAWERMA                          Sandwiches
#       2017-06-01  CHEESE DOG170 GM (MB)                     Sandwiches
#       2017-06-01  EGG MAYONNAISE PARATHA165GM MB            Sandwiches
#
#                                         Category  \
# Store YYYY-MM-DD
# 1     2017-06-01  Wrap
#       2017-06-01  Sub Roll
#       2017-06-01  Wrap
#
#                                           SubCat  SuppCode TransactionDate  \
# Store YYYY-MM-DD
# 1     2017-06-01  Wrap                               110.0      2017-06-01
#       2017-06-01  Sub Roll                            32.0      2017-06-01
#       2017-06-01  Wrap                                32.0      2017-06-01
#
#                   QtySold  unitcost  COGS  SalesAmount  Promotion
# Store YYYY-MM-DD
# 1     2017-06-01        1       7.0   7.0         12.0        0.0
#       2017-06-01        1       4.0   4.0          6.0        0.0
#       2017-06-01        1       3.0   3.0          5.0        0.0

# %%
datosx.groupby(['YYYY-MM-DD','PSA']).get_group((dt.date(2017,6,20),'Sandwiches')).head(3)
# Out:
#                   Unnamed: 0         UniqueField  RECEIPTNO  ItemCode  \
# Store YYYY-MM-DD
# 1     2017-06-20      419800  0000015859 2093110       5859   20060.0
#       2017-06-20      419839  0000015882 2132714       5882   20020.0
#       2017-06-20      419861  0000015892 2145536       5892   20017.0
#
#                                                       Name         PSA  \
# Store YYYY-MM-DD
# 1     2017-06-20  CHICKEN PARATHA165GM MODRN BKR            Sandwiches
#       2017-06-20  EGG MAYONNAISE PARATHA165GM MB            Sandwiches
#       2017-06-20  GRILLED CHICKEN BURGER175GR MB            Sandwiches
#
#                                         Category  \
# Store YYYY-MM-DD
# 1     2017-06-20  Wrap
#       2017-06-20  Wrap
#       2017-06-20  Sub Roll
#
#                                           SubCat  SuppCode TransactionDate  \
# Store YYYY-MM-DD
# 1     2017-06-20  Wrap                                32.0      2017-06-20
#       2017-06-20  Wrap                                32.0      2017-06-20
#       2017-06-20  Sub Roll                            32.0      2017-06-20
#
#                   QtySold  unitcost  COGS  SalesAmount  Promotion
# Store YYYY-MM-DD
# 1     2017-06-20        1      3.25  3.25          5.5        0.0
#       2017-06-20        1      3.00  3.00          5.0        0.0
#       2017-06-20        1      4.70  4.70          8.0        0.0

# %%
datosx.groupby(['YYYY-MM-DD','PSA'])[['COGS','SalesAmount']].aggregate(np.sum).head(3)
# Out:
#                             COGS  SalesAmount
# YYYY-MM-DD PSA
# 2017-06-01 Babies         28.900        33.50
#            Bakery       1313.132      2040.50
#            Beauty Aids   417.090       494.25

# %%
datosx.groupby(['YYYY-MM-DD','PSA']).size().head(3)
# Out:
# YYYY-MM-DD  PSA
# 2017-06-01  Babies           2
#             Bakery         436
#             Beauty Aids     32
# dtype: int64

# %%
grupodato = datosx.groupby(['YYYY-MM-DD','PSA']).size().head(3)
print(grupodato.index.values[0])
print(grupodato.values[0])
# Out:
# (Timestamp('2017-06-01 00:00:00'), 'Babies')
# 2

# %%
grupodato
# Out:
# YYYY-MM-DD  PSA
# 2017-06-01  Babies           2
#             Bakery         436
#             Beauty Aids     32
# dtype: int64

# %%
grupodato.describe()
# Out:
# count      3.000000
# mean     156.666667
# std      242.374366
# min        2.000000
# 25%       17.000000
# 50%       32.000000
# 75%      234.000000
# max      436.000000
# dtype: float64

# %% [markdown]
# ## Aggregation functions
# ---------------------------------------

# %%
datosx.groupby(['Store','PSA'])['SalesAmount'].agg([len,np.sum,np.mean,np.std]).head(10)
# Out:
#                                  len       sum       mean        std
# Store PSA
# 1     Babies                     1.0     72.00  72.000000        NaN
#       Bakery                  1319.0   4958.25   3.759098   2.943691
#       Beauty Aids               48.0    949.00  19.770833   9.925766
#       Beverage                2673.0   8240.25   3.082772   3.561833
#       Cigarette               1031.0  10187.50   9.881183  12.175006
#       Cleaning                  44.0    606.25  13.778409  11.581011
#       Condiment                 27.0    176.75   6.546296   4.594121
#       Confectionery           1436.0   5974.75   4.160689   4.662465
#       Counter FF (Beverages)  1436.0   7647.00   5.325209   3.733839
#       Counter FF (Foods)       390.0   2988.50   7.662821   4.879370

# %%
datosx.groupby(['Store','PSA'])['SalesAmount'].agg([len,np.sum,np.mean,np.std]).\
rename(columns={'len':'Qx.','sum':'Total','mean':'Avg.','std':'Var'}).head(10)
# Out:
#                                  Qx.     Total       Avg.        Var
# Store PSA
# 1     Babies                     1.0     72.00  72.000000        NaN
#       Bakery                  1319.0   4958.25   3.759098   2.943691
#       Beauty Aids               48.0    949.00  19.770833   9.925766
#       Beverage                2673.0   8240.25   3.082772   3.561833
#       Cigarette               1031.0  10187.50   9.881183  12.175006
#       Cleaning                  44.0    606.25  13.778409  11.581011
#       Condiment                 27.0    176.75   6.546296   4.594121
#       Confectionery           1436.0   5974.75   4.160689   4.662465
#       Counter FF (Beverages)  1436.0   7647.00   5.325209   3.733839
#       Counter FF (Foods)       390.0   2988.50   7.662821   4.879370

# %%
datosx.groupby(['Store','PSA']).agg({'SalesAmount': np.sum,'COGS':len}).head(10)
# Out:
#                               SalesAmount    COGS
# Store PSA
# 1     Babies                        72.00     1.0
#       Bakery                      4958.25  1319.0
#       Beauty Aids                  949.00    48.0
#       Beverage                    8240.25  2673.0
#       Cigarette                  10187.50  1031.0
#       Cleaning                     606.25    44.0
#       Condiment                    176.75    27.0
#       Confectionery               5974.75  1436.0
#       Counter FF (Beverages)      7647.00  1436.0
#       Counter FF (Foods)          2988.50   390.0

# %% [markdown]
# ## Custom calculations with Lambda functions
# ----------------------------------------------------------------------

# %%
key = lambda x: x.day
# Python offers the ability to use day, week, month and automatically detect and group dates
zscore = lambda x: (x - x.mean()) / x.std()

datooss = datos.copy()
datooss.reset_index(inplace=True)
datooss = datooss[['YYYY-MM-DD','SalesAmount']]

# %%
datooss.set_index('YYYY-MM-DD',inplace=True)

# %%
datooss.head(10)
# Out:
#             SalesAmount
# YYYY-MM-DD
# 2017-06-01         6.25
# 2017-06-01         5.00
# 2017-06-01         3.50
# 2017-06-01        12.00
# 2017-06-01         1.50
# 2017-06-01         6.00
# 2017-06-01         2.50
# 2017-06-01         1.25
# 2017-06-01        16.00
# 2017-06-01         3.00

# %%
transformed = datooss.groupby(key).transform(zscore)

# %%
transformed.plot(kind='hist',bins=200,xlim=(-20,50));

# %%
datiiss = datos.copy()
datiiss.reset_index(inplace=True)
datiiss = datiiss[['YYYY-MM-DD','SalesAmount']]
datiiss.set_index(['YYYY-MM-DD'],inplace=True)

# %%
f = lambda x: x.fillna(x.max())
transformed = datiiss.transform(f)

# %%
transformed.head(10)
# Out:
#             SalesAmount
# YYYY-MM-DD
# 2017-06-01         6.25
# 2017-06-01         5.00
# 2017-06-01         3.50
# 2017-06-01        12.00
# 2017-06-01         1.50
# 2017-06-01         6.00
# 2017-06-01         2.50
# 2017-06-01         1.25
# 2017-06-01        16.00
# 2017-06-01         3.00

# %%
datosx.groupby('YYYY-MM-DD').rolling(4)['SalesAmount'].mean().head()
# Out:
# YYYY-MM-DD
# 2017-06-01       NaN
# 2017-06-01       NaN
# 2017-06-01       NaN
# 2017-06-01    6.6875
# 2017-06-01    5.5000
# Name: SalesAmount, dtype: float64

# %%
datosx.groupby('YYYY-MM-DD')['SalesAmount'].expanding().sum().head()
# Out:
# YYYY-MM-DD
# 2017-06-01     6.25
# 2017-06-01    11.25
# 2017-06-01    14.75
# 2017-06-01    26.75
# 2017-06-01    28.25
# Name: SalesAmount, dtype: float64

# %%
datosx.groupby('YYYY-MM-DD')['SalesAmount'].apply(lambda x:x.describe()).head()
# Out:
# YYYY-MM-DD
# 2017-06-01  count    6864.000000
#             mean        6.079123
#             std         7.402726
#             min      -100.000000
#             25%         2.000000
# Name: SalesAmount, dtype: float64
