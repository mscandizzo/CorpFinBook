# %% [markdown]
# ## Matplotlib Cheatsheet part 3
# -------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
spy = pd.read_csv('SPY.csv',index_col=0)
spy.index = pd.to_datetime(spy.index)

# %% [markdown]
# ### Matplotlib Style Sheet
# ------------------------------
#
# Play around with the different styles available

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
def visuals():
    plt.figure(figsize=(16,8))
   
    plt.subplot(121)
    plt.scatter(spy['Close'].values,spy['Volume'].values, c=spy['Close'].values, marker='o')
    plt.colorbar()
    plt.grid(True)
    plt.xlabel('SPY Close Price',fontsize=12)
    plt.ylabel('SPY Volume',fontsize=12)
    plt.title('SPY Close-Volume Scatter Plot',fontsize=16)
    
    plt.subplot(122)
    plt.plot(spy['Close'],'--',lw=2,marker='o',color='blue',markerfacecolor='royalblue', 
         markeredgecolor='k',label='Close')
    plt.plot(spy['High']+10,'--',lw=2,marker='2',color='green',markerfacecolor='lime',label='High')
    plt.plot(spy['Low']-10,'--',lw=2,marker='1',color='red',markerfacecolor='darkred',label='Close')
    plt.xticks(fontsize=10, rotation=45)
    plt.title('SPY 2019 Historical Evolution',fontsize=14)
    plt.ylabel('SPY Price',fontsize=12)
    plt.xlabel('Dates',fontsize=12)
    plt.grid(True)  # adds a grid
    plt.axis('tight') # adjusts the axis ranges
    plt.ylim(220,350)
    plt.legend(loc=2);

# %% [markdown]
# ### Applying a different style only to an specific chart

# %%
with plt.style.context('grayscale'):
    visuals()

# %%
with plt.style.context('ggplot'):
    visuals()

# %%
with plt.style.context('Solarize_Light2'):
    visuals()

# %%
with plt.style.context('tableau-colorblind10'):
    visuals()

# %%
with plt.style.context('dark_background'):
    visuals()
