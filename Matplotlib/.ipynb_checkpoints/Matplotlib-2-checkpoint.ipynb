# %% [markdown]
# ### Matplotlib Cheatsheet part 2
# -----------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import datetime as dt
import matplotlib as mpl
import pandas as pd
plt.style.use('classic')
datos = pd.read_excel('MonteCarlo.xlsx',sheet_name='MonteCarlo',index_col=0)
spy = pd.read_csv('SPY.csv',index_col=0)
spy.index = pd.to_datetime(spy.index)

# %%
x = np.random.rand(100)
y1 = np.random.rand(len(x))
y2 = 1.2 + np.exp(x)
sizes = 1000 * np.random.rand(100)

# %% [markdown]
# ### MATLAB - style interface
# --------------------------------
#
# #### Scatter plots customization
#
# Scatter plots provide full control to the individual properties of each plot ( size, face color, edge color, etc.)

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(121) # (rows, columns, panel number)
plt.scatter(x,y1, color = 'indigo', alpha = 0.5, edgecolors ='white',
           label ='no correl', s =sizes, cmap ='viridis');
plt.xlabel('no correlation',fontsize =16)
plt.grid(True)
plt.legend(loc = 0, fontsize = 16)

ax2 = fig.add_subplot(122)
plt.scatter(x,y2, color ='green', alpha = 0.5, edgecolors = 'grey',
           label = 'correl', s =sizes, cmap ='viridis');
plt.xlabel('strong correlation',fontsize =16)
plt.grid(True)
plt.legend(loc = 0, fontsize =16)

plt.show();

# %% [markdown]
# ### Object Oriented interface

# %%
# 1st create a grid of plots
# ax will be an array of two Axes objects
x = np.linspace(-2 * np.pi, 2 * np.pi, 1000)

fig, ax = plt.subplots(2, figsize = (12,8))
ax[0].plot(x,np.sin(x),label = '$\sin(x)$')
ax[1].plot(x,np.cos(x),label = '$\cos(x)$')
plt.axis([-8,8,-1.5,1.5])
plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# ### 3D Shaded labels
# ---------------------

# %%
from matplotlib import patheffects

data = np.random.rand(70)

# %%
from matplotlib import patheffects
plt.figure(figsize=(12,8))
plt.plot(spy.index.values,spy['Close'].values,'--',lw=3,color='darkblue')
plt.grid('tight')
title_text_obj = plt.title("SPY Historical Evolution", fontsize = 20,
                          verticalalignment = 'bottom')
title_text_obj.set_path_effects([patheffects.withSimplePatchShadow()])
# offset_xy = set the angle of the shadow
# shadow_rgbFace = set the color of the shadow
# patch_alpha = setup the transparency of the shadow

pe = patheffects.withSimplePatchShadow(offset = (1, -1), shadow_rgbFace = (1,0,0),
                                      alpha = 0.8)
xlabel_obj = plt.xlabel('Dates', fontsize = 20,alpha =0.7)
xlabel_obj.set_path_effects([pe])
ylabel_obj = plt.ylabel('SPY Price', fontsize = 20,alpha =0.7)
ylabel_obj.set_path_effects([pe])
plt.show();

# %% [markdown]
# ### Customized Legends
# ------------------

# %%
plt.figure(figsize=(12,8))
ax = plt.gca()

row_labels = ['Simul 1','Simul 2','Simul 3','Simul 4']
col_labels = ['Step 1','Step 2','Step 3', 'Step 4']
path1 = [10,20,30,40]
path2 = [12,22,32,42]
path3 = [15,25,35,45]
path4 = [18,28,38,48]
y = [1,2,3,4]
table_vals= [[10,20,30,40],[12,22,32,42],[15,25,35,45],[18,28,38,48]]
row_colors = ['red','gold','green','lavender']
my_table = plt.table(cellText = table_vals,colWidths = [.1]* 4,
                    rowLabels = row_labels, colLabels=col_labels,
                    rowColours = row_colors, loc='upper center')
plt.plot(y,path1,lw=2,color=row_colors[0], marker ="8")
plt.plot(y,path2,lw=2,color=row_colors[1], marker ="^")
plt.plot(y,path3,lw=2,color=row_colors[2], marker ="*")
plt.plot(y,path4,lw=2,color=row_colors[3], marker ="<")
plt.show()

# %%
import pandas as pd
import numpy as np
datos = pd.read_excel('MonteCarlo.xlsx',sheet_name='MonteCarlo',index_col=0)

# %%
np.around(datos.iloc[: ,0:4].values,decimals=2)
# Out:
# array([[36.24, 36.24, 36.24, 36.24],
#        [32.45, 37.68, 35.99, 39.34],
#        [32.24, 37.92, 35.  , 39.17],
#        [26.35, 33.07, 35.52, 44.55],
#        [24.37, 41.05, 29.52, 41.3 ],
#        [21.85, 37.66, 24.28, 40.06],
#        [25.17, 38.24, 22.44, 36.46],
#        [29.44, 36.79, 21.98, 35.37],
#        [29.78, 36.07, 20.12, 39.38],
#        [31.22, 34.78, 22.8 , 32.97],
#        [31.51, 30.99, 20.99, 32.95]])

# %%
plt.figure(figsize=(12,8))
fig, axs =plt.subplots()
axs.axis('tight')
axs.axis('off')
col_labels = ['Simulation 1','Simulation 2','Simulation 3','Simulation 4']
row_labels = ['Step 1','Step 2','Step 3','Step 4','Step 5','Step 6','Step 7','Step 8','Step 9','Step 10','Step 11']
table_vals=np.around(datos.iloc[: ,0:4].values,decimals=2)
row_colors = ['darkslategray','powderblue','darkmagenta','lightgreen',
          'sienna','royalblue','mistyrose','lavender','tomato','gold','green']
my_table = axs.table(cellText = table_vals,colWidths = [.2]* 4,
                     rowLabels = row_labels, colLabels=col_labels,
                    rowColours = row_colors, loc='center')
my_table.set_fontsize(12)
my_table.scale(1, 2)
plt.show();

# %% [markdown]
# ### Grid Set up & Configuration
# ---------------------------

# %%
plt.figure(figsize=(12,8))
axes1 = plt.subplot2grid((3,3),(0,0), colspan =3)
axes2 = plt.subplot2grid((3,3),(1,0), colspan =2)
axes3 = plt.subplot2grid((3,3),(1,2))
axes4 = plt.subplot2grid((3,3),(2,0))
axes5 = plt.subplot2grid((3,3),(2,1), colspan =2)

# tidy up tick labels size
all_axes = plt.gcf().axes
for ax in all_axes:
    for ticklabel in ax.get_xticklabels() + ax.get_yticklabels():
        ticklabel.set_fontsize(10)
        
plt.suptitle('Demo of subplot2grid',fontsize = 16)
plt.show()

# %%
datos[0]
# Out:
# 0     36.240000
# 1     32.445543
# 2     32.239778
# 3     26.353699
# 4     24.372024
# 5     21.847139
# 6     25.173614
# 7     29.440403
# 8     29.784696
# 9     31.223837
# 10    31.513215
# Name: 0, dtype: float64

# %%
plt.figure(figsize=(12,8))
axes1 = plt.subplot2grid((3,3),(0,0), colspan =3)
axes1.plot(datos[0],'--',color='red',lw=3,marker='^')
axes1.plot(datos[5],'--',color='green',lw=3,marker='d')

axes2 = plt.subplot2grid((3,3),(1,0), colspan =2)
axes2.plot(datos[1],'--',color='blue',lw=1,marker='8')
axes2.plot(datos[6],'--',color='orange',lw=1,marker='1')

axes3 = plt.subplot2grid((3,3),(1,2))
axes3.plot(datos[2],'--',color='green',lw=2,marker='*')
axes3.plot(datos[7],'--',color='brown',lw=2,marker='P')

axes4 = plt.subplot2grid((3,3),(2,0))
axes4.plot(datos[3],'--',color='magenta',marker= 'o')
axes4.plot(datos[8],'--',color='yellow',marker= 'H')

axes5 = plt.subplot2grid((3,3),(2,1), colspan =2)
axes5.plot(datos[4],'--',color='orange',marker='v')
axes5.plot(datos[9],'--',color='orange',marker='<')

# tidy up tick labels size
all_axes = plt.gcf().axes
for ax in all_axes:
    for ticklabel in ax.get_xticklabels() + ax.get_yticklabels():
        ticklabel.set_fontsize(10)
        
plt.suptitle('Monte Carlo Simulation Paths',fontsize = 16)
plt.show()

# %%
# MATLAB oriented version

fig = plt.figure(figsize=(12,8))
plt.style.use('seaborn-white')
ax1 = plt.axes()
ax2 = plt.axes([.65,.65,.2,.2])

# %%
fig = plt.figure(figsize=(12,8))
plt.style.use('seaborn-white')
ax1 = plt.axes()
ax1.plot(datos[0],'--',color='red',lw=3,marker='^')
ax1.plot(datos[5],'--',color='green',lw=3,marker='d')
plt.title('Large Chart Title', fontsize=16)
ax2 = plt.axes([.2,.65,.2,.2])
ax2.plot(datos[1],'--',color='blue',lw=1,marker='8')
ax2.plot(datos[6],'--',color='orange',lw=1,marker='1')
plt.title('Small Chart Title', fontsize=10);

# %%
# Object Oriented version

fig = plt.figure()
ax1 = fig.add_axes([.1,.5,.8,.4], xticklabels=[],ylim=(-1.2,1.2))
ax2 = fig.add_axes([.1,.1,.8,.4], ylim=(-1.2,1.2))
x = np.linspace(0,10)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x));

# %%
fig = plt.figure(figsize = (12,8))
fig.subplots_adjust(hspace=.4,wspace=.4) # it adds space in between plots
for i in range(1,7):
    plt.subplot(2,3,i)
    plt.text(.5,.5, str((2,3,i)),fontsize = 18, ha='center')

# %%
spy = pd.read_csv('SPY.csv',index_col=0)
spy.index = pd.to_datetime(spy.index)

# %%
fig = plt.figure(figsize = (12,8))
fig.subplots_adjust(hspace=.4,wspace=.4) # it adds space in between plots
for counter, field in enumerate(spy.columns):
    plt.subplot(2,3,(counter+1))
    plt.plot(spy[field])
    plt.xticks(fontsize=8, rotation=45)
    plt.title('SPY '+field+' field',fontsize=12)
    plt.ylabel('SPY Price',fontsize = 10)
    plt.xlabel('Dates',fontsize = 10)

# %%
grid = plt.GridSpec(2,3, wspace=0.4,hspace=0.3)
plt.subplot(grid[0,0])
plt.subplot(grid[0,1:])
plt.subplot(grid[1,:2])
plt.subplot(grid[1,2]);

# %%
x = [1,2,3,4]
y = [5,4,3,2]
z = [15,30,45,10]
grid = plt.GridSpec(2,3, wspace=0.4,hspace=0.3)
plt.subplot(grid[0,0])
plt.bar(x,y, color = 'darkred', alpha = 0.7)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.title('Bar Chart',fontsize=12);
plt.subplot(grid[0,1:])
plt.boxplot(x)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.title('Boxplot Chart',fontsize=12);
plt.subplot(grid[1,:2])
plt.plot(x,y, linewidth = 5, color = 'royalblue', ls='-.',marker='8')
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.title('Line Chart',fontsize=12);
plt.subplot(grid[1,2])
labels = ['Laptops', 'Tablets', 'Servers', 'Accessories']
# explode must be onf len(x) or None
explode = [.1,.1,.1,.1]

plt.pie(z, explode = explode, labels= labels,
       autopct= '%1.1f%%', startangle = 67, textprops={'fontsize':10},
       colors=['cornflowerblue','darkorange','cyan','firebrick'])
plt.title('Computer Products Sales',fontsize=12);
plt.show()

# %%
def process_signals(x,y):
    return (1-(x**2 +y**2)) * np.exp(-y**3/3)

x = np.arange(-1.5,1.5,.1)
y = np.arange(-1.5,1.5,.1)
X,Y = np.meshgrid(x,y)
Z = process_signals(X,Y)

N = np.arange(-1.5,1.5,.1)

# %%
Z.shape
# Out:
# (30, 30)

# %%
plt.figure(figsize=(12,8))
CS = plt.contour(Z,N, linewidths = 2, cmap=mpl.cm.jet)
plt.clabel(CS,inline= True, fmt='%1.1f', fontsize = 10)
plt.colorbar(CS)
plt.title('My function: $z=(1-x^2+y^2) e^{-(y^3)/3}$')
plt.show()

# %%
x = np.linspace(0,50,1000)
plt.plot(x, x + 1,linestyle = '-')  # solid
plt.plot(x, x + 2,linestyle = '--') # dashed 
plt.plot(x, x + 3,linestyle = '-.') # dashdot
plt.plot(x, x + 4,linestyle = ':')  # dotted

# %% [markdown]
# ### Matplotlib Gotchas:
# -----------------------
#
# From Object oriented to Matlab interface
#
# <ul>
# 	<li>plt.xlabel() &rarr; ax.set_xlabel()</li>
# 	<li>plt.ylabel() &rarr; ax.set_ylabel()</li>
#     <li>plt.xlim() &rarr; </li>
#     <li>plt.lim() &rarr; ax.set_ylim()</li>
#     <li>plt.title() &rarr; ax.set_title()</li>
# </ul>

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 80)

fig, ax = plt.subplots(1, figsize = (12,8))
ax.plot(x,np.sin(x),'-p',label = '$\sin(x)$', color='gray',
       markersize = 15, linewidth =4,
       markerfacecolor ='white', markeredgecolor = 'gray',
       markeredgewidth = 2)
plt.axis([-8,8,-1.5,1.5])
plt.axis('tight')
plt.legend()
plt.show()

# %% [markdown]
# ### Error bars
# --------------

# %%
x = np.arange(1,10,1)
y = np.log(x)
xe = 0.1 + np.abs(np.random.rand(len(y)))

plt.figure(figsize=(12,8))
#draw and show error bar
plt.bar(x,y,yerr=xe, width=0.5, align='center',
       ecolor = 'darkred', edgecolor='black',lw=2,color='royalblue',label ='experiment #1',capsize=5,error_kw={'lw':3})

# give some explanations
plt.xlabel('# measurement',fontsize=12)
plt.ylabel('Measured values',fontsize=12)
plt.title('Measurements',fontsize=16)
plt.legend(loc=9,fontsize=12);

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x,y,yerr = dy,marker='o',markeredgecolor='darkblue',markerfacecolor='darkred' ,
             markersize=8,ecolor='royalblue',elinewidth=2,capsize=4,capthick=4)
plt.xlabel('# measurement',fontsize=12)
plt.ylabel('Measured values',fontsize=12)
plt.title('Measurements',fontsize=16)
plt.show();

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x,y,yerr = dy, fmt='o', color = 'black',
            ecolor = 'lightgray', elinewidth = 3, capsize = 0);

# %% [markdown]
# ### Grid Spec Chart
# --------------------------

# %%
#create normally distributed data
mean = [0,0]
cov  = [[1,1],[1,2]]
x,y = np.random.multivariate_normal(mean,cov,3000).T

# set up axes with gridspec
fig = plt.figure(figsize=(6,6))
grid = plt.GridSpec(4,4,hspace=.2,wspace=.2)
main_ax = fig.add_subplot(grid[:-1,1:])
y_hist = fig.add_subplot(grid[:-1,0], xticklabels=[],sharey=main_ax)
x_hist = fig.add_subplot(grid[-1,1:], yticklabels=[],sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x,y,'ok',markersize=3,alpha=.2)

# histogram on the attached 
x_hist.hist(x, 40, histtype='stepfilled',orientation='vertical',color='gray')
x_hist.invert_yaxis()
y_hist.hist(y,40,histtype='stepfilled',orientation='horizontal',color='gray')
y_hist.invert_xaxis();

# %% [markdown]
# ### Annotations
# -------------

# %%
births = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv')

# %%
quartiles = np.percentile(births['births'],[25,50,75])
mu, sig = quartiles[1],0.74*(quartiles[2]-quartiles[0])
births = births.query('(births>@mu - 5 * @sig) & (births <@mu + 5 * @sig)')

births['day'] = births['day'].astype(int)

births.index = pd.to_datetime(10000 * births.year + 100 * births.month + births.day, format='%Y%m%d')
births_by_date = births.pivot_table('births', [births.index.month, births.index.day])
births_by_date.index = [pd.datetime(2012,month,day) for (month, day) in births_by_date.index]
# Out:
# <ipython-input-32-8067b83d22d5>:9: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   births_by_date.index = [pd.datetime(2012,month,day) for (month, day) in births_by_date.index]

# %%
fig , ax = plt.subplots(figsize=(12,8))
births_by_date.plot(ax=ax,linewidth=3)

# add labels to the plot
ax.text('2012-1-1',3950 ,"New Year's Day" ,size=14,color='red')
ax.text('2012-7-4',4250 ,"Independence Day" ,size=14,color='green',ha='center')
ax.text('2012-9-4',4850 ,"Labor Day" ,size=14,color='brown',ha='center')
ax.text('2012-10-31',4600 ,"Halloween" ,size=14,color='orange',ha='right')
ax.text('2012-11-25',4450 ,"Thanksgiving" ,size=14,color='purple',ha='center')
ax.text('2012-12-25',3850 ,"Christmas" ,size=14,color='magenta',ha='right')

# label the axes
ax.set_title("USA births by day of year (1969,1988)", fontsize = 16)
ax.set_ylabel('Average daily births',fontsize = 14)
ax.set_xlabel('Dates',fontsize = 14)
# format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));

# %%
spy = pd.read_csv('SPY.csv',index_col=0)
spy.index = pd.to_datetime(spy.index)

# %%
fig , ax = plt.subplots(figsize=(12,8))
spy['Adj Close'].plot(ax=ax,linewidth=3)

# add labels to the plot
ax.text('2019-1-1',230 ,"New Year's Day" ,size=14,color='red',ha='left')
ax.text('2019-7-4',260 ,"Independence Day" ,size=14,color='green',ha='center')
ax.text('2019-9-4',270 ,"Labor Day" ,size=14,color='brown',ha='center')
ax.text('2019-10-31',277 ,"Halloween" ,size=14,color='orange',ha='right')
ax.text('2019-11-25',290 ,"Thanksgiving" ,size=14,color='purple',ha='center')
ax.text('2019-12-25',330 ,"Christmas" ,size=14,color='magenta',ha='center')

# label the axes
ax.set_title("S&P 500 Historical Evolution", fontsize = 16)
ax.set_ylabel('SPY Value',fontsize = 14)
ax.set_xlabel('Dates',fontsize = 14)
# format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));

# %%
fig, ax = plt.subplots(figsize=(12,8))
spy['Adj Close'].plot(ax=ax)

#Add labels to the plot
ax.annotate("New Year's Day", xy=('2019-1-1',240), xycoords='data',xytext=(30,-20),
           textcoords='offset points',arrowprops=dict(arrowstyle="->",connectionstyle='arc3,rad=-0.2'))

ax.annotate("Independence Day", xy=('2019-7-4',290), xycoords='data',bbox=dict(boxstyle='round',fc='none',ec='gray'),
           xytext=(10,-60),textcoords='offset points',ha='center',arrowprops=dict(arrowstyle="->"))

ax.annotate("Labor Day", xy=('2019-9-4',290), xycoords='data',xytext=(0,30),
            textcoords='offset points',ha='center')

ax.annotate('Halloween', xy=('2019-10-31', 295),  xycoords='data',
            xytext=(-80, -80), textcoords='offset points',
            arrowprops=dict(arrowstyle="fancy",
                            fc="0.6", ec="none",
                            connectionstyle="angle3,angleA=0,angleB=-90"))

ax.annotate('Thanksgiving', xy=('2019-11-25', 306),  xycoords='data',
            xytext=(-100, 60), textcoords='offset points',
            bbox=dict(boxstyle="round4,pad=.5", fc="0.9"),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle,angleA=0,angleB=80,rad=20"))


ax.annotate('Christmas', xy=('2019-12-25', 317),  xycoords='data',
             xytext=(0, -50), textcoords='offset points',
             size=13, ha='center', va="center",
             bbox=dict(boxstyle="round", alpha=0.1),
             arrowprops=dict(arrowstyle="wedge,tail_width=0.5", alpha=0.1));

# Label the axes
ax.set_title("S&P 500 Historical Evolution", fontsize = 16)
ax.set_ylabel('SPY Value',fontsize = 14)
ax.set_xlabel('Dates',fontsize = 14)

# Format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));

ax.set_ylim(220, 340);

# %%
fig , ax = plt.subplots(facecolor='lightgray')
ax.axis([0,10,0,10])

# transform = ax.transData is the default, but we'll specify it anyway
ax.text(1,5,". Data:(1,5)", transform=ax.transData)
ax.text(.5,.1,". Axes:(.5,.1)",transform=ax.transAxes)
ax.text(.2,.2,". Figure:(.2,.2)",transform=fig.transFigure);

# %%
fix, ax = plt.subplots()
x = np.linspace(0,20,1000)
ax.plot(x, np.cos(x))
ax.axis('equal')
ax.annotate('local maximum', xy=(6.28,1),xytext=(10,4),
           arrowprops=dict(facecolor='black',shrink=0.05))
ax.annotate('local minimum', xy=(5*np.pi,-1),xytext=(2,-6),
           arrowprops=dict(arrowstyle="->",connectionstyle='angle3,angleA=0,angleB=-90'))
# Out:
# Text(2, -6, 'local minimum')

# %%
fig, ax = plt.subplots(figsize=(12,8))
births_by_date.plot(ax=ax)

#Add labels to the plot
ax.annotate("New Year's Day", xy=('2012-1-1',4100), xycoords='data',xytext=(50,-30),
           textcoords='offset points',arrowprops=dict(arrowstyle="->",connectionstyle='arc3,rad=-0.2'))

ax.annotate("Independence Day", xy=('2012-7-4',4250), xycoords='data',bbox=dict(boxstyle='round',fc='none',ec='gray'),
           xytext=(10,-40),textcoords='offset points',ha='center',arrowprops=dict(arrowstyle="->"))

ax.annotate("Labor Day", xy=('2012-9-4',4850), xycoords='data',xytext=(0,-20),
            textcoords='offset points',ha='center')

ax.annotate('Halloween', xy=('2012-10-31', 4600),  xycoords='data',
            xytext=(-80, -40), textcoords='offset points',
            arrowprops=dict(arrowstyle="fancy",
                            fc="0.6", ec="none",
                            connectionstyle="angle3,angleA=0,angleB=-90"))

ax.annotate('Thanksgiving', xy=('2012-11-25', 4500),  xycoords='data',
            xytext=(-120, -60), textcoords='offset points',
            bbox=dict(boxstyle="round4,pad=.5", fc="0.9"),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle,angleA=0,angleB=80,rad=20"))


ax.annotate('Christmas', xy=('2012-12-25', 3850),  xycoords='data',
             xytext=(-30, 0), textcoords='offset points',
             size=13, ha='right', va="center",
             bbox=dict(boxstyle="round", alpha=0.1),
             arrowprops=dict(arrowstyle="wedge,tail_width=0.5", alpha=0.1));

# Label the axes
ax.set(title='USA births by day of year (1969-1988)',
       ylabel='average daily births')

# Format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));

ax.set_ylim(3600, 5400);

# %%
from matplotlib.ticker import AutoMinorLocator
minorLocator = AutoMinorLocator()
fig, ax = plt.subplots()
plt.plot(spy.index.values,spy.Close.values,lw=3)

ax.yaxis.set_minor_locator(minorLocator)

plt.tick_params(which='both', width=2)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=4, color='red')

plt.show()

# %%
ax = plt.axes()
ax.plot(np.random.rand(50))
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %% [markdown]
# ### Reducing or increasing the number of ticks

# %%
fig, ax = plt.subplots(4,4, sharex=True, sharey=True)

# %%
fig, ax = plt.subplots(4,4, sharex=True, sharey=True)
# for every axis set the x and y major locator
for axi in ax.flat:
    axi.xaxis.set_major_locator(plt.MaxNLocator(3))
    axi.yaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax =plt.subplots(figsize=(8,6)) # it adds space in between plots
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(3))
ax.yaxis.set_major_locator(plt.MaxNLocator(3))
plt.plot(spy.index.values,spy.Close.values)
plt.title('MaxNLocator')
plt.show();

fig, ax =plt.subplots(figsize=(8,6)) # it adds space in between plots
ax = plt.axes()
ax.xaxis.set_major_locator(plt.LinearLocator(10))
ax.yaxis.set_major_locator(plt.LinearLocator(10))
plt.plot(spy.index.values,spy.Close.values)
plt.title('LinearLocator')
plt.show();

fig, ax =plt.subplots(figsize=(8,6)) # it adds space in between plots
ax = plt.axes()
#ax.xaxis.set_major_locator(plt.MultipleLocator(2))
ax.yaxis.set_major_locator(plt.MultipleLocator(5))
plt.plot(spy.index.values,spy.Close.values)
plt.title('MultipleLocator')
plt.show();

fig, ax =plt.subplots(figsize=(8,6)) # it adds space in between plots
ax = plt.axes()
#ax.xaxis.set_major_locator(plt.IndexLocator())
ax.yaxis.set_major_locator(plt.IndexLocator(base=5,offset=2))
plt.plot(spy.index.values,spy.Close.values)
plt.title('IndexLocator')
plt.show();

fig, ax =plt.subplots(figsize=(8,6)) # it adds space in between plots
ax = plt.axes()
ax.xaxis.set_major_locator(plt.NullLocator())
ax.yaxis.set_major_locator(plt.NullLocator())
plt.plot(spy.index.values,spy.Close.values)
plt.title('NullLocator')
plt.show();

# %%
fig, ax = plt.subplots()
x = np.linspace(0,3*np.pi,1000)
ax.plot(x,np.sin(x),lw=3,label='Sine')
ax.plot(x,np.cos(x),lw=3,label='Cosine')

# Set up grid, legend, and limits
ax.grid(True)
ax.legend(frameon=False)
ax.axis('equal')
ax.set_xlim(0,3*np.pi)
ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi/2))
ax.xaxis.set_minor_locator(plt.MultipleLocator(np.pi/4))
plt.show();
